# %% [markdown]
# # **[기업의 파산을 조기 예측하기 위한 분류 모델링]**

# %% [markdown]
# ## **[# 기업 파산 예측 DATA SET]**

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# **data.csv는**
# - 96개의 columns와 6,819 개의 rows로 구성되어 있습니다.
#  - dtypes: float64(93), int64(3)

# %% [markdown]
# ### 2. 수집 방법

# %% [markdown]
# * 캐글 데이터셋 활용
# * Company Bankruptcy Prediction 다운로드

# %% [markdown]
# ### 3.   수집 경로

# %% [markdown]
# * Company Bankruptcy Prediction Dataset
# - URL : (https://www.kaggle.com/datasets/fedesoriano/company-bankruptcy-prediction)

# %% [markdown]
# ### 4.   데이터의 논리적 구조

# %% [markdown]
# #### **Columns: Bankruptcy_org_df**
#
#  - dtypes: float64(93), int64(3)
# ---  ------                                                    --------------  -----
# #### 1)  <클래스 레이블>
#  - 0   Bankrupt?                                                 6819 non-null   int64
#
# #### 2)  <continuous형 피쳐>
#  - 1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  - 2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  - 3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  - 4    Operating Gross Margin                                   6819 non-null   float64
#  - 5    Realized Sales Gross Margin                              6819 non-null   float64
# -  6    Operating Profit Rate                                    6819 non-null   float64
# -  7    Pre-tax net Interest Rate                                6819 non-null   float64
# -  8    After-tax net Interest Rate                              6819 non-null   float64
# -  9    Non-industry income and expenditure/revenue              6819 non-null   float64
# -  10   Continuous interest rate (after tax)                     6819 non-null   float64
# -   11   Operating Expense Rate                                   6819 non-null   float64
# -   12   Research and development expense rate                    6819 non-null   float64
# -   13   Cash flow rate                                           6819 non-null   float64
# -   14   Interest-bearing debt interest rate                      6819 non-null   float64
# -   15   Tax rate (A)                                             6819 non-null   float64
# -   16   Net Value Per Share (B)                                  6819 non-null   float64
# -   17   Net Value Per Share (A)                                  6819 non-null   float64
# -   18   Net Value Per Share (C)                                  6819 non-null   float64
# -   19   Persistent EPS in the Last Four Seasons                  6819 non-null   float64
# -   20   Cash Flow Per Share                                      6819 non-null   float64
# -   21   Revenue Per Share (Yuan ¥)                               6819 non-null   float64
# -   22   Operating Profit Per Share (Yuan ¥)                      6819 non-null   float64
# -   23   Per Share Net profit before tax (Yuan ¥)                 6819 non-null   float64
# -   24   Realized Sales Gross Profit Growth Rate                  6819 non-null   float64
# -   25   Operating Profit Growth Rate                             6819 non-null   float64
# -   26   After-tax Net Profit Growth Rate                         6819 non-null   float64
# -   27   Regular Net Profit Growth Rate                           6819 non-null   float64
# -  28   Continuous Net Profit Growth Rate                        6819 non-null   float64
# -   29   Total Asset Growth Rate                                  6819 non-null   float64
# -   30   Net Value Growth Rate                                    6819 non-null   float64
# -   31   Total Asset Return Growth Rate Ratio                     6819 non-null   float64
# -   32   Cash Reinvestment %                                      6819 non-null   float64
# -   33   Current Ratio                                            6819 non-null   float64
# -   34   Quick Ratio                                              6819 non-null   float64
# -   35   Interest Expense Ratio                                   6819 non-null   float64
# -   36   Total debt/Total net worth                               6819 non-null   float64
# -   37   Debt ratio %                                             6819 non-null   float64
# -   38   Net worth/Assets                                         6819 non-null   float64
# -   39   Long-term fund suitability ratio (A)                     6819 non-null   float64
# -   40   Borrowing dependency                                     6819 non-null   float64
# -   41   Contingent liabilities/Net worth                         6819 non-null   float64
# -   42   Operating profit/Paid-in capital                         6819 non-null   float64
# -   43   Net profit before tax/Paid-in capital                    6819 non-null   float64
# -   44   Inventory and accounts receivable/Net value              6819 non-null   float64
# -   45   Total Asset Turnover                                     6819 non-null   float64
# -   46   Accounts Receivable Turnover                             6819 non-null   float64
# -   47   Average Collection Days                                  6819 non-null   float64
# -   48   Inventory Turnover Rate (times)                          6819 non-null   float64
# -   49   Fixed Assets Turnover Frequency                          6819 non-null   float64
# -   50   Net Worth Turnover Rate (times)                          6819 non-null   float64
# -   51   Revenue per person                                       6819 non-null   float64
# -   52   Operating profit per person                              6819 non-null   float64
# -   53   Allocation rate per person                               6819 non-null   float64
# -   54   Working Capital to Total Assets                          6819 non-null   float64
# -   55   Quick Assets/Total Assets                                6819 non-null   float64
# -   56   Current Assets/Total Assets                              6819 non-null   float64
# -   57   Cash/Total Assets                                        6819 non-null   float64
# -   58   Quick Assets/Current Liability                           6819 non-null   float64
# -   59   Cash/Current Liability                                   6819 non-null   float64
# -   60   Current Liability to Assets                              6819 non-null   float64
# -   61   Operating Funds to Liability                             6819 non-null   float64
# -   62   Inventory/Working Capital                                6819 non-null   float64
# -   63   Inventory/Current Liability                              6819 non-null   float64
# -   64   Current Liabilities/Liability                            6819 non-null   float64
# -   65   Working Capital/Equity                                   6819 non-null   float64
# -   66   Current Liabilities/Equity                               6819 non-null   float64
# -   67   Long-term Liability to Current Assets                    6819 non-null   float64
# -   68   Retained Earnings to Total Assets                        6819 non-null   float64
# -   69   Total income/Total expense                               6819 non-null   float64
# -   70   Total expense/Assets                                     6819 non-null   float64
# -   71   Current Asset Turnover Rate                              6819 non-null   float64
# -   72   Quick Asset Turnover Rate                                6819 non-null   float64
# -   73   Working capitcal Turnover Rate                           6819 non-null   float64
# -   74   Cash Turnover Rate                                       6819 non-null   float64
# -   75   Cash Flow to Sales                                       6819 non-null   float64
# -   76   Fixed Assets to Assets                                   6819 non-null   float64
# -   77   Current Liability to Liability                           6819 non-null   float64
# -   78   Current Liability to Equity                              6819 non-null   float64
# -   79   Equity to Long-term Liability                            6819 non-null   float64
# -   80   Cash Flow to Total Assets                                6819 non-null   float64
# -   81   Cash Flow to Liability                                   6819 non-null   float64
# -   82   CFO to Assets                                            6819 non-null   float64
# -   83   Cash Flow to Equity                                      6819 non-null   float64
# -   84   Current Liability to Current Assets                      6819 non-null   float64
# -   86   Net Income to Total Assets                               6819 non-null   float64
# -   87   Total assets to GNP price                                6819 non-null   float64
# -   88   No-credit Interval                                       6819 non-null   float64
# -   89   Gross Profit to Sales                                    6819 non-null   float64
# -   90   Net Income to Stockholder's Equity                       6819 non-null   float64
# -   91   Liability to Equity                                      6819 non-null   float64
# -   92   Degree of Financial Leverage (DFL)                       6819 non-null   float64
# -   93   Interest Coverage Ratio (Interest expense to EBIT)       6819 non-null   float64
# -   95   Equity to Liability                                      6819 non-null   float64
#
# #### 3)  <Category형 피쳐>
# -   85   Liability-Assets Flag                                    6819 non-null   int64
# -   94   Net Income Flag                                          6819 non-null   int64

# %% [markdown]
# ### 5.   데이터의 물리적 저장 구조

# %% [markdown]
# - Company Bankruptcy Prediction Dataset CSV 파일

# %% [markdown]
# ### 6. 참고 페이지

# %% [markdown]
# * 원천.
# - URL : (https://archive.ics.uci.edu/dataset/572/taiwanese+bankruptcy+prediction)
#
# * 관련 논문.
# -  URL : (https://www.sciencedirect.com/science/article/abs/pii/S0377221716000412)

# %% [markdown]
# ### 7. 피처 설명

# %% [markdown]
# ### 1) y
# #### Bankrupt?: 클래스 레이블
#
# ### 2) X
# - X1 : ROA(C) before interest and depreciation before interest: Return On Total Assets(C) --> 이자 전 ROA(C) 및 이자 전 감가 상각: 총 자산 수익률(C)
#
# - X2 : ROA(A) before interest and % after tax: Return On Total Assets(A) --> 이자 전 ROA(A) 및 세금 후 %: 총 자산 수익률(A)
#
# - X3 : ROA (B) ROA(B) before interest and depreciation after tax: Return On Total Assets(B) --> 이자 및 감가상각 전: 총자산수익률(B)
#
# - X4  : Operating Gross Margin: Gross Profit/Net Sales  --> 영업이익률: 매출총이익/순매출액
#
# - X5 : Realized Sales Gross Margin: Realized Gross Profit/Net Sales -->  실현매출이익률: 실현총이익/순매출액
#
# - X6: Operating Profit Rate: Operating Income/Net Sales --> 영업이익률: 영업이익/ 순매출
#
# - X7 : Pre-tax net Interest Rate: Pre-Tax Income/Net Sales  --> 세전 순이자율: 세전이익/순매출
#
# - X8 : After-tax net Interest Rate: Net Income/Net Sales --> 세후 순이자율: 당기순이익/순매출
#
# - X9 :   Non-industry income and expenditure/revenue: Net Non-operating Income Ratio --> 비산업수익 및 지출/수익: 순영업외수익 비율
#
# - X10 : Continuous interest rate (after tax): Net Income-Exclude Disposal Gain or Loss/Net Sales --> 연속이자율(세후): 당기순이익-처분손익제외손익/순매출액
#
# - X11 : Operating Expense Rate: Operating Expenses/Net Sales --> 영업비용률: 영업비용/순매출액
#
# - X12 : Research and development expense rate: (Research and Development Expenses)/Net Sales --> 연구개발비율: (연구개발비)/순매출액
#
# - X13 :  Cash flow rate: Cash Flow from Operating/Current Liabilities --> 현금흐름비율: 영업/유동부채 현금흐름
#
# - X14 :  Interest-bearing debt interest rate: Interest-bearing Debt/Equity --> 이자부 부채 이자율: 이자부 부채/자본
#
# - X15 : Tax rate (A): Effective Tax Rate --> 세율(A): 유효세율
#
# - X16 : Net Value Per Share (B): Book Value Per Share(B) --> 주당순가치(B): 장부가 주당 순가치(B)
#
# - X17 : Net Value Per Share (A): Book Value Per Share(A) --> 주당 순가치(A): 주당 장부가치(A)
#
# - X18 :  Net Value Per Share (C): Book Value Per Share(C) --> 주당 순가치(C): 주당 순가치(C)
#
# - X19 : Persistent EPS in the Last Four Seasons: EPS-Net Income --> 지난 4계절의 지속적인 EPS: EPS -순이익
#
# - X20 : Cash Flow Per Share --> 주당 현금 흐름
#
# - X21 : Revenue Per Share (Yuan ¥): Sales Per Share --> 주당 수익(Yuan ¥): 주당 매출
#
# - X22 : Operating Profit Per Share (Yuan ¥): Operating Income Per Share --> 주당 영업 이익(Yuan ¥): 주당 영업 이익
#
# - X23 : Per Share Net profit before tax (Yuan ¥): Pretax Income Per Share --> 주당 세전 순이익(Yuan ¥): 주당 세전 이익
#
# - X24 : Realized Sales Gross Profit Growth Rate --> 총 실현 매출 이익증가율
#
# - X25 : Operating Profit Growth Rate: Operating Income Growth --> 영업이익증가율: 영업이익증가율
#
# - X26 : After-tax Net Profit Growth Rate: Net Income Growth --> 세후순이익증가율: 순이익증가율
#
# - X27 : Regular Net Profit Growth Rate: Continuing Operating Income after Tax Growth --> 정기순이익증가율: 세후증가후 계속영업이익
#
# - X28 : Continuous Net Profit Growth Rate: Net Income-Excluding Disposal Gain or Loss Growth --> 지속적인 순이익증가율: 당기순이익 - 처분손익 제외
#
# - X29 : Total Asset Growth Rate: Total Asset Growth -->  총자산증가율: 총자산증가율
#
# - X30 : Net Value Growth Rate: Total Equity Growth -->  순가치증가율: 총자산증가율
#
# - X31: Total Asset Return Growth Rate Ratio: Return on Total Asset Growth --> 총자산수익률증가율: 총자산증가율
#
# - X32 :  Cash Reinvestment %: Cash Reinvestment Ratio --> 현금 재투자 %: 현금 재투자 비율
#
# - X33 : Current Ratio --> 유동 비율
#
# - X34 : Quick Ratio: Acid Test --> 당좌 비율: 산성 테스트
#
# - X35 : Interest Expense Ratio: Interest Expenses/Total Revenue -->  이자 비용 비율: 이자 비용/총 수익
#
# - X36 : Total debt/Total net worth: Total Liability/Equity Ratio --> 총 부채/순자산 총액: 총 부채/자본 비율
#
# - X37 : Debt ratio %: Liability/Total Assets -->  부채 비율 % : 부채/총자산
#
# - X38 :  Net worth/Assets: Equity/Total Assets --> 순자산/자산: 자기자본/총자산
#
# - X39 : Long-term fund suitability ratio (A): (Long-term Liability+Equity)/Fixed Assets --> 장기자금적합성비율(A): (장기부채+자기자본)/고정자산
#
# - X40 : Borrowing dependency: Cost of Interest-bearing Debt --> 차입의존성: 이자부부채비용
#
# - X41 :  Contingent liabilities/Net worth: Contingent Liability/Equity --> 우발부채/순자산: 우발부채/자본
#
# - X42 : Operating profit/Paid-in capital: Operating Income/Capital --> 영업이익/납입자본: 영업이익/자본
#
# - X43 :  Net profit before tax/Paid-in capital: Pretax Income/Capital --> 세전순이익/납입자본: 세전이익/자본
#
# - X44 :  Inventory and accounts receivable/Net value: (Inventory+Accounts Receivables)/Equity --> 재고 및 미수금/순가치: (재고+미수금)/자본
#
# - X45 :  Total Asset Turnover --> 총 자산 회전율
#
# - X46 : Accounts Receivable Turnover --> 미수금 회전율
#
# - X47 :  Average Collection Days: Days Receivable Outstanding -->평균 수금 일수: 미수금 미수 일수
#
# - X48 : Inventory Turnover Rate (times) --> 재고 회전율(회)
#
# - X49 : Fixed Assets Turnover Frequency --> 고정 자산 회전율 빈도
#
# - X50 : Net Worth Turnover Rate (times): Equity Turnover --> 순자산회전율(배): 자기자본회전율
#
# - X51 : Revenue per person: Sales Per Employee --> 1인당 매출: 직원 1인당 매출
#
# - X52 : Operating profit per person: Operation Income Per Employee --> 1인당 영업이익: 직원 1인당 영업이익
#
# - X53 : Allocation rate per person: Fixed Assets Per Employee --> 1인당 배부율: 직원 1인당 고정자산
#
# - X54 : Working Capital to Total Assets --> 총 운전 자본 자산
#
# - X55 : Quick Assets/Total Assets --> 약식 자산/총 자산
#
# - X56 : Current Assets/Total Assets -->  유동 자산/총 자산
#
# - X57 :  Cash/Total Assets --> 현금/총 자산
#
# - X58 : Quick Assets/Current Liability --> 당좌 자산/유동 부채
#
# - X59 : Cash/Current Liability --> 현금/유동 부채
#
# - X60 : Current Liability to Assets --> 자산유동 부채
#
# - X61 : Operating Funds to Liability --> 영업 자금 부채
#
# - X62 : Inventory/Working Capital --> 재고/운전 자본
#
# - X63 : Inventory/Current Liability --> 재고/유동 부채
#
# - X64 : Current Liabilities/Liability --> 유동 부채/부채
#
# - X65 : Working Capital/Equity --> 운전 자본/자본
#
# - X66 : Current Liabilities/Equity --> 유동부채/자본
#
# - X67 : Long-term Liability to Current Assets --> 유동자산에 대한 장기부채
#
# - X68 :  Retained Earnings to Total Assets --> 총자산에 대한 이익잉여금
#
# - X69 : Total income/Total expense --> 총수익/총비용
#
# - X70 : Total expense/Assets --> 총비용/자산
#
# - X71 : Current Asset Turnover Rate: Current Assets to Sales --> 유동자산회전율: 유동자산매출액
#
# - X72 : Quick Asset Turnover Rate: Quick Assets to Sales --> 빠른 자산회전율 비율: 판매에 대한 빠른 자산
#
# - X73 : Working capitcal Turnover Rate: Working Capital to Sales -->  운전 자본 회전율: 판매에 대한 운전 자본
#
# - X74 : Cash Turnover Rate: Cash to Sales --> 현금 회전율: 현금에서 매출로
#
# - X75 : Cash Flow to Sales -->  현금 흐름에서 매출로
#
# - X76 : Fixed Assets to Assets --> 고정 자산에서 자산으로
#
# - X77 : Current Liability to Liability --> 유동 부채에서 부채로
#
# - X78 : Current Liability to Equity  --> 유동 부채에서 자본으로
#
# - X79 : Equity to Long-term Liability --> 자본에서 장기 부채로
#
# - X80 : Cash Flow to Total Assets --> 현금 흐름에서 총 자산으로
#
# - X81 : Cash Flow to Liability --> 부채에 대한 현금 흐름
#
# - X82 :  CFO to Assets --> 자산에 대한 CFO
#
# - X83 : Cash Flow to Equity --> 자본에 대한 현금 흐름
#
# - X84 :  Current Liability to Current Assets --> 유동 자산에 대한 유동 부채
#
# - X85 :  Liability-Assets Flag: 1 if Total Liability exceeds Total Assets, 0 otherwise --> 부채-자산 플래그: 총 부채가 총 자산을 초과하는 경우 1, 그렇지 않은 경우 0
#
# - X86 : Net Income to Total Assets --> 총 자산에 대한 순이익
#
# - X87 : Total assets to GNP price --> 총 자산 GNP 가격으로
#
# - X88 : No-credit Interval --> 무신용 구간
#
# - X89 : Gross Profit to Sales --> 매출 총 이익
#
# - X90 :  Net Income to Stockholder's Equity --> 자기 자본에 대한 순이익
#
# - X91 : Liability to Equity --> 자기 자본에 대한 부채
#
# - X92 : Degree of Financial Leverage (DFL) -->  DFL(재무 레버리지)
#
# - X93 : Interest Coverage Ratio (Interest expense to EBIT) --> 이자 보상 비율(EBIT에 대한 이자 비용)
#
# - X94 : Net Income Flag: 1 if Net Income is Negative for the last two years, 0 otherwise -->  순이익  플래그: 지난 2년 동안 순이익이 마이너스인 경우 1, 그렇지 않은 경우 0
#
# - X95 : Equity to Liability --> 부채의 지분
