# %% [markdown]
# ## 1. **[기업의 파산을 조기 예측하기 위한 분류 모델링]**

# %% [markdown]
# *   1. 기간 : 2023-06-15 ~ 2023-06-22 (총 7일)
#
#
#
# *   2. 리더 : 장예지
#
#
# *   3. 정의 : 기업의 파산위기를 감지하기 위한 예측 모델링
#
#
# *   4. 목적 :
#      - (1) 기업에서 파산을 예측하여 위기 상황을 조기에 감지하고 대응하기 위함.
#      - (2) 금융 기관에서 기관의 파산 위험을 고려하여 대출 승인 및 리스크 관리를 하기 위함.
#
#
# *   5. 목표
#      - : 파산 위기에 처한 기업을 조기에 식별하여 경영자들이 조치를 취할 수 있도록 도움줄 수 있다.
#      - : 금융 기관은 대출 신청을 받은 기업의 파산 위험을 평가하고, 이를 기반으로 대출을 승인하거나 거절하며 리스크를 관리할 수 있다.
#
#
# *   6. 범위
#      - : 1999-2009년 동안 Taiwan Economic Journal의 파산 데이터
#
#
# *   7. 타겟 및 피처
#      - (1) target : 파산여부를 0과 1로 표현한 Bankrupt?
#      - (2) features : target을 제외한 95개 컬럼
#
#
#
# *   8. 분류 알고리즘 :
#      - (1) 로지스틱 회귀(Logistic Regression)
#      - (2) 결정 트리(Decision Tree)
#      - (3) 랜덤포레스트(Random Forest)
#      - (4) 그래디언트 부스팅(Gradient Boosting) : XGBoost, LightGBM
#
#
#      9. 성능 지표 :
#      - (1) 재현율(Recall)
#      - (2) ROC-AUC

# %% [markdown]
# ## 2. **[할 일 목록]**

# %% [markdown]
# - ~~1. 프로젝트 데이터 정의서 작성~~
# - 2. 데이터 이해 및 탐색 - 데이터 피처 및 타겟 이해
# - 3. 분류 모델링 - 로지스틱 회귀, 결정트리, XGBoost, LightGBM, 앙상블
# - 4. 최종 모델 선정
# - 5. 발표 준비

# %% [markdown]
# ### **[1일차 - 6/15일]**
# 1. ~~주제선정~~
# 2. 데이터 피처 및 타겟 이해

# %% [markdown]
# ### **[2일차 - 6/16일]**
# 1. ??
# 2. ??

# %% [markdown]
# ## 3. **[이슈 항목 및 추후과제]**

# %% [markdown]
# ### **1. ??**

# %% [markdown]
# ~~~
# ???.
# ~~~
# - ??
